# %% [markdown]
# <a href="https://colab.research.google.com/github/espSiyam/Deep-Learning/blob/master/Upscale_Videos_TecoGAN_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TecoGAN on Colab
# Official Github Repo: https://github.com/thunil/TecoGAN <br>
# Original Colab Notebook by ak9250: https://colab.research.google.com/github/ak9250/TecoGAN/blob/master/Tecogan.ipynb#scrollTo=32PrvHTyQj9i
#
# This notebook was modified by Ahabbscience Studio (M. Ahabb)

# %% [markdown]
# ##Check GPU

# %%
# !nvidia-smi
# Out:
# Sun Feb 28 17:43:07 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ##Clone Repo

# %%
from IPython.display import clear_output
# !git clone https://github.com/thunil/TecoGAN.git
# %cd TecoGAN
# !pip3 install -r requirements.txt
clear_output()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##Download Models and Sample Files

# %%
# !python3 runGan.py 0
clear_output()

# %% [markdown]
# ##Add your own Files via youtube_dl or google drive

# %% [markdown]
# Run to create directory "My_video", here you can add your Google Drive or youtube_dl file

# %%
# !mkdir /content/TecoGAN/LR/My_video
#!mkdir /content/TecoGAN/HR/My_video
# Out:
# mkdir: cannot create directory ‘/content/TecoGAN/LR/My_video’: File exists

# %%
# %cd /content/TecoGAN/LR/My_video
#!ffmpeg  -i /content/sample_data/orange.mp4 %04d.png
# !ffmpeg  -i /content/drive/MyDrive/Deep_learning/GAN/Gupi.mp4 %04d.png
# Out:
# /content/TecoGAN/LR/My_video
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/content/drive/MyDrive/Deep_learning/GAN/Gupi.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 512
#     compatible_brands: mp42
#     creation_time   : 2021-02-28T17:39:45.000000Z
#     media_type      : 0
#     season_number   : 0
#     episode_sort    : 0
#     hd_video        : 0
#     iTunMOVI        : <?xml version="1.0" encoding="UTF-8"?><!DOCTYPE plist PUBLIC "-//Apple Computer//DTD PLIST 1.0//EN"  "http://www.apple.com/DTDs/PropertyList-1.0.dtd"><plist version="1.0"><dict><key>studio</key><string>studio</string><key>cast</key><array><dict><key>name<
#   Duration: 00:00:18.81, start: 0.000000, bitrate: 1059 kb/s
#     Stream #0:0(eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 320x260 [SAR 1:1 DAR 16:13], 846 kb/s, 25 fps, 25 tbr, 250 tbn, 50 tbc (default)
#     Metadata:
#       creation_time   : 2021-02-28T17:39:45.000000Z
#       handler_name    : VideoHandler
#       encoder         : h264
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 197 kb/s (default)
#     Metadata:
#       creation_time   : 2021-02-28T17:39:45.000000Z
#       handler_name    : SoundHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '%04d.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 512
#     compatible_brands: mp42
#     iTunMOVI        : <?xml version="1.0" encoding="UTF-8"?><!DOCTYPE plist PUBLIC "-//Apple Computer//DTD PLIST 1.0//EN"  "http://www.apple.com/DTDs/PropertyList-1.0.dtd"><plist version="1.0"><dict><key>studio</key><string>studio</string><key>cast</key><array><dict><key>name<
#     media_type      : 0
#     season_number   : 0
#     episode_sort    : 0
#     hd_video        : 0
#     encoder         : Lavf57.83.100
#     Stream #0:0(eng): Video: png, rgb24, 320x260 [SAR 1:1 DAR 16:13], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc (default)
#     Metadata:
#       creation_time   : 2021-02-28T17:39:45.000000Z
#       handler_name    : VideoHandler
#       encoder         : Lavc57.107.100 png
# frame=  470 fps=129 q=-0.0 Lsize=N/A time=00:00:18.80 bitrate=N/A speed=5.18x
# video:22169kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %% [markdown]
# ##Upscale your footage frames on default model (Interface mode)

# %%
cd /content/TecoGAN
# Out:
# /content/TecoGAN

# %% [markdown]
# Edit runGan.py to add your file directory

# %%
# %%writefile runGan.py
'''
several running examples, run with
python3 runGan.py 1 # the last number is the run case number
runcase == 1    inference a trained model
runcase == 2    calculate the metrics, and save the numbers in csv
runcase == 3    training TecoGAN
runcase == 4    training FRVSR
runcase == ...  coming... data preparation and so on...
'''
import os, subprocess, sys, datetime, signal, shutil
 
runcase = int(sys.argv[1])
print ("Testing test case %d" % runcase)
 
def preexec(): # Don't forward signals.
    os.setpgrp()
    
def mycall(cmd, block=False):
    if not block:
        return subprocess.Popen(cmd)
    else:
        return subprocess.Popen(cmd, preexec_fn = preexec)
    
def folder_check(path):
    try_num = 1
    oripath = path[:-1] if path.endswith('/') else path
    while os.path.exists(path):
        print("Delete existing folder " + path + "?(Y/N)")
        decision = input()
        if decision == "Y":
            shutil.rmtree(path, ignore_errors=True)
            break
        else:
            path = oripath + "_%d/"%try_num
            try_num += 1
            print(path)
    
    return path
 
if( runcase == 0 ): # download inference data, trained models
    # download the trained model
    if(not os.path.exists("./model/")): os.mkdir("./model/")
    cmd1 = "wget https://ge.in.tum.de/download/data/TecoGAN/model.zip -O model/model.zip;"
    cmd1 += "unzip model/model.zip -d model; rm model/model.zip"
    subprocess.call(cmd1, shell=True)
    
    # download some test data
    cmd2 = "wget https://ge.in.tum.de/download/data/TecoGAN/vid3_LR.zip -O LR/vid3.zip;"
    cmd2 += "unzip LR/vid3.zip -d LR; rm LR/vid3.zip"
    subprocess.call(cmd2, shell=True)
    
    cmd2 = "wget https://ge.in.tum.de/download/data/TecoGAN/tos_LR.zip -O LR/tos.zip;"
    cmd2 += "unzip LR/tos.zip -d LR; rm LR/tos.zip"
    subprocess.call(cmd2, shell=True)
    
    # download the ground-truth data
    if(not os.path.exists("./HR/")): os.mkdir("./HR/")
    cmd3 = "wget https://ge.in.tum.de/download/data/TecoGAN/vid4_HR.zip -O HR/vid4.zip;"
    cmd3 += "unzip HR/vid4.zip -d HR; rm HR/vid4.zip"
    subprocess.call(cmd3, shell=True)
    
    cmd3 = "wget https://ge.in.tum.de/download/data/TecoGAN/tos_HR.zip -O HR/tos.zip;"
    cmd3 += "unzip HR/tos.zip -d HR; rm HR/tos.zip"
    subprocess.call(cmd3, shell=True)
    
elif( runcase == 1 ): # inference a trained model
    
    dirstr = './results/' # the place to save the results
    testpre = ['My_video'] # the test cases
    
 
    if (not os.path.exists(dirstr)): os.mkdir(dirstr)
    
    # run these test cases one by one:
    for nn in range(len(testpre)):
        cmd1 = ["python3", "main.py",
            "--cudaID", "0",            # set the cudaID here to use only one GPU
            "--output_dir",  dirstr,    # Set the place to put the results.
            "--summary_dir", os.path.join(dirstr, 'log/'), # Set the place to put the log. 
            "--mode","inference", 
            "--input_dir_LR", os.path.join("./LR/", testpre[nn]),   # the LR directory 
            #"--input_dir_HR", os.path.join("./HR/", testpre[nn]),  # the HR directory
            # one of (input_dir_HR,input_dir_LR) should be given
            "--output_pre", testpre[nn], # the subfolder to save current scene, optional
            "--num_resblock", "16",  # our model has 16 residual blocks, 
            # the pre-trained FRVSR and TecoGAN mini have 10 residual blocks
            "--checkpoint", './model/TecoGAN',  # the path of the trained model,
            "--output_ext", "png"               # png is more accurate, jpg is smaller
        ]
        mycall(cmd1).communicate()
 
elif( runcase == 2 ): # calculate all metrics, and save the csv files, should use png
 
    testpre = ["calendar"] # just put more scenes to evaluate all of them
    dirstr = './results/'  # the outputs
    tarstr = './HR/'       # the GT
 
    tar_list = [(tarstr+_) for _ in testpre]
    out_list = [(dirstr+_) for _ in testpre]
    cmd1 = ["python3", "metrics.py",
        "--output", dirstr+"metric_log/",
        "--results", ",".join(out_list),
        "--targets", ",".join(tar_list),
    ]
    mycall(cmd1).communicate()
    
elif( runcase == 3 ): # Train TecoGAN
    '''
    In order to use the VGG as a perceptual loss,
    we download from TensorFlow-Slim image classification model library:
    https://github.com/tensorflow/models/tree/master/research/slim    
    '''
    VGGPath = "model/" # the path for the VGG model, there should be a vgg_19.ckpt inside
    VGGModelPath = os.path.join(VGGPath, "vgg_19.ckpt")
    if(not os.path.exists(VGGPath)): os.mkdir(VGGPath)
    if(not os.path.exists(VGGModelPath)):
        # Download the VGG 19 model from 
        print("VGG model not found, downloading to %s"%VGGPath)
        cmd0 = "wget http://download.tensorflow.org/models/vgg_19_2016_08_28.tar.gz -O " + os.path.join(VGGPath, "vgg19.tar.gz")
        cmd0 += ";tar -xvf " + os.path.join(VGGPath,"vgg19.tar.gz") + " -C " + VGGPath + "; rm "+ os.path.join(VGGPath, "vgg19.tar.gz")
        subprocess.call(cmd0, shell=True)
        
    '''
    Use our pre-trained FRVSR model. If you want to train one, try runcase 4, and update this path by:
    FRVSRModel = "ex_FRVSRmm-dd-hh/model-500000"
    '''
    FRVSRModel = "model/ourFRVSR" 
    if(not os.path.exists(FRVSRModel+".data-00000-of-00001")):
        # Download our pre-trained FRVSR model
        print("pre-trained FRVSR model not found, downloading")
        cmd0 = "wget http://ge.in.tum.de/download/2019-TecoGAN/FRVSR_Ours.zip -O model/ofrvsr.zip;"
        cmd0 += "unzip model/ofrvsr.zip -d model; rm model/ofrvsr.zip"
        subprocess.call(cmd0, shell=True)
    
    TrainingDataPath = "/mnt/netdisk/video_data/" 
    
    '''Prepare Training Folder'''
    # path appendix, manually define it, or use the current datetime, now_str = "mm-dd-hh"
    now_str = datetime.datetime.now().strftime("%m-%d-%H")
    train_dir = folder_check("ex_TecoGAN%s/"%now_str)
    # train TecoGAN, loss = l2 + VGG54 loss + A spatio-temporal Discriminator
    cmd1 = ["python3", "main.py",
        "--cudaID", "0", # set the cudaID here to use only one GPU
        "--output_dir", train_dir, # Set the place to save the models.
        "--summary_dir", os.path.join(train_dir,"log/"), # Set the place to save the log. 
        "--mode","train",
        "--batch_size", "4" , # small, because GPU memory is not big
        "--RNN_N", "10" , # train with a sequence of RNN_N frames, >6 is better, >10 is not necessary
        "--movingFirstFrame", # a data augmentation
        "--random_crop",
        "--crop_size", "32",
        "--learning_rate", "0.00005",
        # -- learning_rate step decay, here it is not used --
        "--decay_step", "500000", 
        "--decay_rate", "1.0", # 1.0 means no decay
        "--stair",
        "--beta", "0.9", # ADAM training parameter beta
        "--max_iter", "500000", # 500k or more, the one we present is trained for 900k
        "--save_freq", "10000", # the frequency we save models
        # -- network architecture parameters --
        "--num_resblock", "16", # FRVSR and TecoGANmini has num_resblock as 10. The TecoGAN has 16.
        # -- VGG loss, disable with vgg_scaling < 0
        "--vgg_scaling", "0.2",
        "--vgg_ckpt", VGGModelPath, # necessary if vgg_scaling > 0
    ]
    '''Video Training data:
    please udate the TrainingDataPath according to ReadMe.md
    input_video_pre is hard coded as scene in dataPrepare.py at line 142
    str_dir is the starting index for training data
    end_dir is the ending index for training data
    end_dir+1 is the starting index for validation data
    end_dir_val is the ending index for validation data
    max_frm should be duration (in dataPrepare.py) -1
    queue_thread: how many cpu can be used for loading data when training
    name_video_queue_capacity, video_queue_capacity: how much memory can be used
    '''
    cmd1 += [
        "--input_video_dir", TrainingDataPath, 
        "--input_video_pre", "scene",
        "--str_dir", "2000",
        "--end_dir", "2250",
        "--end_dir_val", "2290",
        "--max_frm", "119",
        # -- cpu memory for data loading --
        "--queue_thread", "12",# Cpu threads for the data. >4 to speedup the training
        "--name_video_queue_capacity", "1024",
        "--video_queue_capacity", "1024",
    ]
    '''
    loading the pre-trained model from FRVSR can make the training faster
    --checkpoint, path of the model, here our pre-trained FRVSR is given
    --pre_trained_model,  to continue an old (maybe accidentally stopeed) training, 
        pre_trained_model should be false, and checkpoint should be the last model such as 
        ex_TecoGANmm-dd-hh/model-xxxxxxx
        To start a new and different training, pre_trained_model is True. 
        The difference here is 
        whether to load the whole graph icluding ADAM training averages/momentums/ and so on
        or just load existing pre-trained weights.
    '''
    cmd1 += [ # based on a pre-trained FRVSR model. Here we want to train a new adversarial training
        "--pre_trained_model", # True
        "--checkpoint", FRVSRModel,
    ]
    
    # the following can be used to train TecoGAN continuously
    # old_model = "model/ex_TecoGANmm-dd-hh/model-xxxxxxx" 
    # cmd1 += [ # Here we want to train continuously
    #     "--nopre_trained_model", # False
    #     "--checkpoint", old_model,
    # ]
    
    ''' parameters for GAN training '''
    cmd1 += [
        "--ratio", "0.01",  # the ratio for the adversarial loss from the Discriminator to the Generator
        "--Dt_mergeDs",     # if Dt_mergeDs == False, only use temporal inputs, so we have a temporal Discriminator
                            # else, use both temporal and spatial inputs, then we have a Dst, the spatial and temporal Discriminator
    ]
    ''' if the generator is pre-trained, to fade in the discriminator is usually more stable.
    the weight of the adversarial loss will be weighed with a weight, started from Dt_ratio_0, 
    and increases until Dt_ratio_max, the increased value is Dt_ratio_add per training step
    For example, fading Dst in smoothly in the first 4k steps is 
    "--Dt_ratio_max", "1.0", "--Dt_ratio_0", "0.0", "--Dt_ratio_add", "0.00025"
    '''
    cmd1 += [ # here, the fading in is disabled 
        "--Dt_ratio_max", "1.0",
        "--Dt_ratio_0", "1.0", 
        "--Dt_ratio_add", "0.0", 
    ]
    ''' Other Losses '''
    cmd1 += [
        "--pingpang",           # our Ping-Pang loss
        "--pp_scaling", "0.5",  # the weight of the our bi-directional loss, 0.0~0.5
        "--D_LAYERLOSS",        # use feature layer losses from the discriminator
    ]
    
    pid = mycall(cmd1, block=True) 
    try: # catch interruption for training
        pid.communicate()
    except KeyboardInterrupt: # Ctrl + C to stop current training try to save the last model 
        print("runGAN.py: sending SIGINT signal to the sub process...")
        pid.send_signal(signal.SIGINT)
        # try to save the last model 
        pid.communicate()
        print("runGAN.py: finished...")
        
        
elif( runcase == 4 ): # Train FRVSR, loss = l2 warp + l2 content
    now_str = datetime.datetime.now().strftime("%m-%d-%H")
    train_dir = folder_check("ex_FRVSR%s/"%now_str)
    cmd1 = ["python3", "main.py",
        "--cudaID", "0", # set the cudaID here to use only one GPU
        "--output_dir", train_dir, # Set the place to save the models.
        "--summary_dir", os.path.join(train_dir,"log/"), # Set the place to save the log. 
        "--mode","train",
        "--batch_size", "4" , # small, because GPU memory is not big
        "--RNN_N", "10" , # train with a sequence of RNN_N frames, >6 is better, >10 is not necessary
        "--movingFirstFrame", # a data augmentation
        "--random_crop",
        "--crop_size", "32",
        "--learning_rate", "0.00005",
        # -- learning_rate step decay, here it is not used --
        "--decay_step", "500000", 
        "--decay_rate", "1.0", # 1.0 means no decay
        "--stair",
        "--beta", "0.9", # ADAM training parameter beta
        "--max_iter", "500000", # 500k is usually fine for FRVSR, GAN versions need more to be stable
        "--save_freq", "10000", # the frequency we save models
        # -- network architecture parameters --
        "--num_resblock", "10", # a smaller model
        "--ratio", "-0.01",  # the ratio for the adversarial loss, negative means disabled
        "--nopingpang",
    ]
    '''Video Training data... Same as runcase 3...'''
    TrainingDataPath = "/mnt/netdisk/video_data/"
    cmd1 += [
        "--input_video_dir", TrainingDataPath, 
        "--input_video_pre", "scene",
        "--str_dir", "2000",
        "--end_dir", "2250",
        "--end_dir_val", "2290",
        "--max_frm", "119",
        # -- cpu memory for data loading --
        "--queue_thread", "12",# Cpu threads for the data. >4 to speedup the training
        "--name_video_queue_capacity", "1024",
        "--video_queue_capacity", "1024",
    ]
    
    pid = mycall(cmd1, block=True)
    try: # catch interruption for training
        pid.communicate()
    except KeyboardInterrupt: # Ctrl + C to stop current training try to save the last model 
        print("runGAN.py: sending SIGINT signal to the sub process...")
        pid.send_signal(signal.SIGINT)
        # try to save the last model 
        pid.communicate()
        print("runGAN.py: finished...")
# Out:
# Overwriting runGan.py

# %% [markdown]
# Run interface mode

# %%
# %tensorflow_version 1.x
# !python3 runGan.py 1
# Out:
# Testing test case 1
# WARNING:tensorflow:From main.py:19: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# Using TensorFlow backend.
# WARNING:tensorflow:From main.py:138: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# input shape: [1, 260, 320, 3]
# output shape: [1, 1040, 1280, 3]
# WARNING:tensorflow:From main.py:195: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From main.py:201: The name tf.space_to_depth is deprecated. Please use tf.compat.v1.space_to_depth instead.
#
# WARNING:tensorflow:From main.py:203: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From main.py:206: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /content/TecoGAN/lib/frvsr.py:22: The name tf.image.resize_images is deprecated. Please use tf.image.resize instead.
#
# Finish building the network
# WARNING:tensorflow:From main.py:221: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From main.py:224: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From main.py:227: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From main.py:228: The name tf.local_variables_initializer is deprecated. Please use tf.compat.v1.local_variables_initializer instead.
#
# WARNING:tensorflow:From main.py:230: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From main.py:239: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Loading weights from ckpt model
# Frame evaluation starts!!
# Warming up 5
# Warming up 4
# Warming up 3
# Warming up 2
# Warming up 1
# saving image output_0001
# saving image output_0002
# saving image output_0003
# saving image output_0004
# saving image output_0005
# saving image output_0006
# saving image output_0007
# saving image output_0008
# saving image output_0009
# saving image output_0010
# saving image output_0011
# saving image output_0012
# saving image output_0013
# saving image output_0014
# saving image output_0015
# saving image output_0016
# saving image output_0017
# saving image output_0018
# saving image output_0019
# saving image output_0020
# saving image output_0021
# saving image output_0022
# saving image output_0023
# saving image output_0024
# saving image output_0025
# saving image output_0026
# saving image output_0027
# saving image output_0028
# saving image output_0029
# saving image output_0030
# saving image output_0031
# saving image output_0032
# saving image output_0033
# saving image output_0034
# saving image output_0035
# saving image output_0036
# saving image output_0037
# saving image output_0038
# saving image output_0039
# saving image output_0040
# saving image output_0041
# saving image output_0042
# saving image output_0043
# saving image output_0044
# saving image output_0045
# saving image output_0046
# saving image output_0047
# saving image output_0048
# saving image output_0049
# saving image output_0050
# saving image output_0051
# saving image output_0052
# saving image output_0053
# saving image output_0054
# saving image output_0055
# saving image output_0056
# saving image output_0057
# saving image output_0058
# saving image output_0059
# saving image output_0060
# saving image output_0061
# saving image output_0062
# saving image output_0063
# saving image output_0064
# saving image output_0065
# saving image output_0066
# saving image output_0067
# saving image output_0068
# saving image output_0069
# saving image output_0070
# saving image output_0071
# saving image output_0072
# saving image output_0073
# saving image output_0074
# saving image output_0075
# saving image output_0076
# saving image output_0077
# saving image output_0078
# saving image output_0079
# saving image output_0080
# saving image output_0081
# saving image output_0082
# saving image output_0083
# saving image output_0084
# saving image output_0085
# saving image output_0086
# saving image output_0087
# saving image output_0088
# saving image output_0089
# saving image output_0090
# saving image output_0091
# saving image output_0092
# saving image output_0093
# saving image output_0094
# saving image output_0095
# saving image output_0096
# saving image output_0097
# saving image output_0098
# saving image output_0099
# saving image output_0100
# saving image output_0101
# saving image output_0102
# saving image output_0103
# saving image output_0104
# saving image output_0105
# saving image output_0106
# saving image output_0107
# saving image output_0108
# saving image output_0109
# saving image output_0110
# saving image output_0111
# saving image output_0112
# saving image output_0113
# saving image output_0114
# saving image output_0115
# saving image output_0116
# saving image output_0117
# saving image output_0118
# saving image output_0119
# saving image output_0120
# saving image output_0121
# saving image output_0122
# saving image output_0123
# saving image output_0124
# saving image output_0125
# saving image output_0126
# saving image output_0127
# saving image output_0128
# saving image output_0129
# saving image output_0130
# saving image output_0131
# saving image output_0132
# saving image output_0133
# saving image output_0134
# saving image output_0135
# saving image output_0136
# saving image output_0137
# saving image output_0138
# saving image output_0139
# saving image output_0140
# saving image output_0141
# saving image output_0142
# saving image output_0143
# saving image output_0144
# saving image output_0145
# saving image output_0146
# saving image output_0147
# saving image output_0148
# saving image output_0149
# saving image output_0150
# saving image output_0151
# saving image output_0152
# saving image output_0153
# saving image output_0154
# saving image output_0155
# saving image output_0156
# saving image output_0157
# saving image output_0158
# saving image output_0159
# saving image output_0160
# saving image output_0161
# saving image output_0162
# saving image output_0163
# saving image output_0164
# saving image output_0165
# saving image output_0166
# saving image output_0167
# saving image output_0168
# saving image output_0169
# saving image output_0170
# saving image output_0171
# saving image output_0172
# saving image output_0173
# saving image output_0174
# saving image output_0175
# saving image output_0176
# saving image output_0177
# saving image output_0178
# saving image output_0179
# saving image output_0180
# saving image output_0181
# saving image output_0182
# saving image output_0183
# saving image output_0184
# saving image output_0185
# saving image output_0186
# saving image output_0187
# saving image output_0188
# saving image output_0189
# saving image output_0190
# saving image output_0191
# saving image output_0192
# saving image output_0193
# saving image output_0194
# saving image output_0195
# saving image output_0196
# saving image output_0197
# saving image output_0198
# saving image output_0199
# saving image output_0200
# saving image output_0201
# saving image output_0202
# saving image output_0203
# saving image output_0204
# saving image output_0205
# saving image output_0206
# saving image output_0207
# saving image output_0208
# saving image output_0209
# saving image output_0210
# saving image output_0211
# saving image output_0212
# saving image output_0213
# saving image output_0214
# saving image output_0215
# saving image output_0216
# saving image output_0217
# saving image output_0218
# saving image output_0219
# saving image output_0220
# saving image output_0221
# saving image output_0222
# saving image output_0223
# saving image output_0224
# saving image output_0225
# saving image output_0226
# saving image output_0227
# saving image output_0228
# saving image output_0229
# saving image output_0230
# saving image output_0231
# saving image output_0232
# saving image output_0233
# saving image output_0234
# saving image output_0235
# saving image output_0236
# saving image output_0237
# saving image output_0238
# saving image output_0239
# saving image output_0240
# saving image output_0241
# saving image output_0242
# saving image output_0243
# saving image output_0244
# saving image output_0245
# saving image output_0246
# saving image output_0247
# saving image output_0248
# saving image output_0249
# saving image output_0250
# saving image output_0251
# saving image output_0252
# saving image output_0253
# saving image output_0254
# saving image output_0255
# saving image output_0256
# saving image output_0257
# saving image output_0258
# saving image output_0259
# saving image output_0260
# saving image output_0261
# saving image output_0262
# saving image output_0263
# saving image output_0264
# saving image output_0265
# saving image output_0266
# saving image output_0267
# saving image output_0268
# saving image output_0269
# saving image output_0270
# saving image output_0271
# saving image output_0272
# saving image output_0273
# saving image output_0274
# saving image output_0275
# saving image output_0276
# saving image output_0277
# saving image output_0278
# saving image output_0279
# saving image output_0280
# saving image output_0281
# saving image output_0282
# saving image output_0283
# saving image output_0284
# saving image output_0285
# saving image output_0286
# saving image output_0287
# saving image output_0288
# saving image output_0289
# saving image output_0290
# saving image output_0291
# saving image output_0292
# saving image output_0293
# saving image output_0294
# saving image output_0295
# saving image output_0296
# saving image output_0297
# saving image output_0298
# saving image output_0299
# saving image output_0300
# saving image output_0301
# saving image output_0302
# saving image output_0303
# saving image output_0304
# saving image output_0305
# saving image output_0306
# saving image output_0307
# saving image output_0308
# saving image output_0309
# saving image output_0310
# saving image output_0311
# saving image output_0312
# saving image output_0313
# saving image output_0314
# saving image output_0315
# saving image output_0316
# saving image output_0317
# saving image output_0318
# saving image output_0319
# saving image output_0320
# saving image output_0321
# saving image output_0322
# saving image output_0323
# saving image output_0324
# saving image output_0325
# saving image output_0326
# saving image output_0327
# saving image output_0328
# saving image output_0329
# saving image output_0330
# saving image output_0331
# saving image output_0332
# saving image output_0333
# saving image output_0334
# saving image output_0335
# saving image output_0336
# saving image output_0337
# saving image output_0338
# saving image output_0339
# saving image output_0340
# saving image output_0341
# saving image output_0342
# saving image output_0343
# saving image output_0344
# saving image output_0345
# saving image output_0346
# saving image output_0347
# saving image output_0348
# saving image output_0349
# saving image output_0350
# saving image output_0351
# saving image output_0352
# saving image output_0353
# saving image output_0354
# saving image output_0355
# saving image output_0356
# saving image output_0357
# saving image output_0358
# saving image output_0359
# saving image output_0360
# saving image output_0361
# saving image output_0362
# saving image output_0363
# saving image output_0364
# saving image output_0365
# saving image output_0366
# saving image output_0367
# saving image output_0368
# saving image output_0369
# saving image output_0370
# saving image output_0371
# saving image output_0372
# saving image output_0373
# saving image output_0374
# saving image output_0375
# saving image output_0376
# saving image output_0377
# saving image output_0378
# saving image output_0379
# saving image output_0380
# saving image output_0381
# saving image output_0382
# saving image output_0383
# saving image output_0384
# saving image output_0385
# saving image output_0386
# saving image output_0387
# saving image output_0388
# saving image output_0389
# saving image output_0390
# saving image output_0391
# saving image output_0392
# saving image output_0393
# saving image output_0394
# saving image output_0395
# saving image output_0396
# saving image output_0397
# saving image output_0398
# saving image output_0399
# saving image output_0400
# saving image output_0401
# saving image output_0402
# saving image output_0403
# saving image output_0404
# saving image output_0405
# saving image output_0406
# saving image output_0407
# saving image output_0408
# saving image output_0409
# saving image output_0410
# saving image output_0411
# saving image output_0412
# saving image output_0413
# saving image output_0414
# saving image output_0415
# saving image output_0416
# saving image output_0417
# saving image output_0418
# saving image output_0419
# saving image output_0420
# saving image output_0421
# saving image output_0422
# saving image output_0423
# saving image output_0424
# saving image output_0425
# saving image output_0426
# saving image output_0427
# saving image output_0428
# saving image output_0429
# saving image output_0430
# saving image output_0431
# saving image output_0432
# saving image output_0433
# saving image output_0434
# saving image output_0435
# saving image output_0436
# saving image output_0437
# saving image output_0438
# saving image output_0439
# saving image output_0440
# saving image output_0441
# saving image output_0442
# saving image output_0443
# saving image output_0444
# saving image output_0445
# saving image output_0446
# saving image output_0447
# saving image output_0448
# saving image output_0449
# saving image output_0450
# saving image output_0451
# saving image output_0452
# saving image output_0453
# saving image output_0454
# saving image output_0455
# saving image output_0456
# saving image output_0457
# saving image output_0458
# saving image output_0459
# saving image output_0460
# saving image output_0461
# saving image output_0462
# saving image output_0463
# saving image output_0464
# saving image output_0465
# saving image output_0466
# saving image output_0467
# saving image output_0468
# saving image output_0469
# saving image output_0470
# total time 61.45442080497742, frame number 475

# %% [markdown]
# ##Video Output

# %%
#!ffmpeg -vsync 0 -hwaccel cuvid -c:v mjpeg_cuvid -framerate 24.00 -i /content/TecoGAN/results/My_video/*.png -c:v h264_nvenc quaid2.mp4
# !ffmpeg -f image2 -framerate 30 -i /content/TecoGAN/results/My_video/output_%04d.png -c:v h264_nvenc -preset slow -qp 18 -pix_fmt yuv420p bridge.mp4
# Out:
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from '/content/TecoGAN/results/My_video/output_%04d.png':
#   Duration: 00:00:15.67, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgb24(pc), 1280x1040, 30 fps, 30 tbr, 30 tbn, 30 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (h264_nvenc))
# Press [q] to stop, [?] for help
# Output #0, mp4, to 'bridge.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (h264_nvenc) (Main) (avc1 / 0x31637661), yuv420p, 1280x1040, q=-1--1, 2000 kb/s, 30 fps, 15360 tbn, 30 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 h264_nvenc
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/2000000 buffer size: 4000000 vbv_delay: -1
# frame=  470 fps= 48 q=17.0 Lsize=   11296kB time=00:00:15.63 bitrate=5919.4kbits/s speed=1.59x
# video:11294kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.024731%

# %% [markdown]
# ## Download frames

# %% [markdown]
# Create a Zip file

# %%
from google.colab import files

# !zip -r frames.zip /content/TecoGAN/results/My_video
# Out:
#   adding: content/TecoGAN/results/My_video/ (stored 0%)
#   adding: content/TecoGAN/results/My_video/output_0034.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0132.png (deflated 11%)
#   adding: content/TecoGAN/results/My_video/output_0377.png (deflated 13%)
#   adding: content/TecoGAN/results/My_video/output_0256.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0195.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0128.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0392.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0346.png (deflated 12%)
#   adding: content/TecoGAN/results/My_video/output_0098.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0047.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0437.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0149.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0011.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0330.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0247.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0467.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0328.png (deflated 11%)
#   adding: content/TecoGAN/results/My_video/output_0419.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0026.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0428.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0351.png (deflated 11%)
#   adding: content/TecoGAN/results/My_video/output_0016.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0205.png (deflated 7%)
#   adding: content/TecoGAN/results/My_video/output_0186.png (deflated 8%)
#   adding: content/TecoGAN/results/My_video/output_0064.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0263.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0270.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0056.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0089.png (deflated 11%)
#   adding: content/TecoGAN/results/My_video/output_0397.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0243.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0087.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0097.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0211.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0265.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0018.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0172.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0208.png (deflated 8%)
#   adding: content/TecoGAN/results/My_video/output_0449.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0390.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0081.png (deflated 12%)
#   adding: content/TecoGAN/results/My_video/output_0386.png (deflated 12%)
#   adding: content/TecoGAN/results/My_video/output_0029.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0365.png (deflated 12%)
#   adding: content/TecoGAN/results/My_video/output_0217.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0061.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0204.png (deflated 8%)
#   adding: content/TecoGAN/results/My_video/output_0200.png (deflated 8%)
#   adding: content/TecoGAN/results/My_video/output_0022.png (deflated 8%)
#   adding: content/TecoGAN/results/My_video/output_0216.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0170.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0341.png (deflated 12%)
#   adding: content/TecoGAN/results/My_video/output_0091.png (deflated 11%)
#   adding: content/TecoGAN/results/My_video/output_0420.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0295.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0146.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0069.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0435.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0225.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0134.png (deflated 11%)
#   adding: content/TecoGAN/results/My_video/output_0444.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0096.png (deflated 8%)
#   adding: content/TecoGAN/results/My_video/output_0051.png (deflated 8%)
#   adding: content/TecoGAN/results/My_video/output_0395.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0411.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0159.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0066.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0130.png (deflated 11%)
#   adding: content/TecoGAN/results/My_video/output_0187.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0226.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0176.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0117.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0455.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0304.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0277.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0250.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0322.png (deflated 12%)
#   adding: content/TecoGAN/results/My_video/output_0219.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0461.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0156.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0293.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0160.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0111.png (deflated 8%)
#   adding: content/TecoGAN/results/My_video/output_0439.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0199.png (deflated 8%)
#   adding: content/TecoGAN/results/My_video/output_0220.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0233.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0021.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0453.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0248.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0135.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0202.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0368.png (deflated 12%)
#   adding: content/TecoGAN/results/My_video/output_0254.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0333.png (deflated 12%)
#   adding: content/TecoGAN/results/My_video/output_0121.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0406.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0142.png (deflated 11%)
#   adding: content/TecoGAN/results/My_video/output_0343.png (deflated 13%)
#   adding: content/TecoGAN/results/My_video/output_0396.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0380.png (deflated 13%)
#   adding: content/TecoGAN/results/My_video/output_0203.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0317.png (deflated 12%)
#   adding: content/TecoGAN/results/My_video/output_0245.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0044.png (deflated 8%)
#   adding: content/TecoGAN/results/My_video/output_0242.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0257.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0316.png (deflated 12%)
#   adding: content/TecoGAN/results/My_video/output_0194.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0311.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0012.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0024.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0364.png (deflated 12%)
#   adding: content/TecoGAN/results/My_video/output_0201.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0190.png (deflated 8%)
#   adding: content/TecoGAN/results/My_video/output_0212.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0068.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0210.png (deflated 8%)
#   adding: content/TecoGAN/results/My_video/output_0013.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0144.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0421.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0447.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0374.png (deflated 12%)
#   adding: content/TecoGAN/results/My_video/output_0376.png (deflated 12%)
#   adding: content/TecoGAN/results/My_video/output_0306.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0324.png (deflated 12%)
#   adding: content/TecoGAN/results/My_video/output_0171.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0177.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0359.png (deflated 12%)
#   adding: content/TecoGAN/results/My_video/output_0463.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0164.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0108.png (deflated 11%)
#   adding: content/TecoGAN/results/My_video/output_0288.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0136.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0154.png (deflated 11%)
#   adding: content/TecoGAN/results/My_video/output_0155.png (deflated 11%)
#   adding: content/TecoGAN/results/My_video/output_0372.png (deflated 12%)
#   adding: content/TecoGAN/results/My_video/output_0301.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0002.png (deflated 11%)
#   adding: content/TecoGAN/results/My_video/output_0268.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0387.png (deflated 12%)
#   adding: content/TecoGAN/results/My_video/output_0385.png (deflated 12%)
#   adding: content/TecoGAN/results/My_video/output_0381.png (deflated 12%)
#   adding: content/TecoGAN/results/My_video/output_0148.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0067.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0023.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0189.png (deflated 7%)
#   adding: content/TecoGAN/results/My_video/output_0286.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0003.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0090.png (deflated 11%)
#   adding: content/TecoGAN/results/My_video/output_0320.png (deflated 13%)
#   adding: content/TecoGAN/results/My_video/output_0082.png (deflated 12%)
#   adding: content/TecoGAN/results/My_video/output_0165.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0138.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0319.png (deflated 12%)
#   adding: content/TecoGAN/results/My_video/output_0141.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0409.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0057.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0427.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0338.png (deflated 12%)
#   adding: content/TecoGAN/results/My_video/output_0281.png (deflated 7%)
#   adding: content/TecoGAN/results/My_video/output_0373.png (deflated 12%)
#   adding: content/TecoGAN/results/My_video/output_0276.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0303.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0299.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0113.png (deflated 11%)
#   adding: content/TecoGAN/results/My_video/output_0261.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0458.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0275.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0290.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0092.png (deflated 11%)
#   adding: content/TecoGAN/results/My_video/output_0432.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0025.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0462.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0020.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0045.png (deflated 8%)
#   adding: content/TecoGAN/results/My_video/output_0369.png (deflated 11%)
#   adding: content/TecoGAN/results/My_video/output_0441.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0412.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0095.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0321.png (deflated 12%)
#   adding: content/TecoGAN/results/My_video/output_0278.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0460.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0137.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0085.png (deflated 11%)
#   adding: content/TecoGAN/results/My_video/output_0389.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0407.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0191.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0394.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0103.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0313.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0367.png (deflated 12%)
#   adding: content/TecoGAN/results/My_video/output_0213.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0334.png (deflated 12%)
#   adding: content/TecoGAN/results/My_video/output_0123.png (deflated 11%)
#   adding: content/TecoGAN/results/My_video/output_0040.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0062.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0237.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0050.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0232.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0032.png (deflated 11%)
#   adding: content/TecoGAN/results/My_video/output_0073.png (deflated 11%)
#   adding: content/TecoGAN/results/My_video/output_0104.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0297.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0188.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0384.png (deflated 12%)
#   adding: content/TecoGAN/results/My_video/output_0273.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0287.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0258.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0105.png (deflated 11%)
#   adding: content/TecoGAN/results/My_video/output_0457.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0423.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0110.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0253.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0053.png (deflated 8%)
#   adding: content/TecoGAN/results/My_video/output_0157.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0162.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0267.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0357.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0107.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0442.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0209.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0335.png (deflated 12%)
#   adding: content/TecoGAN/results/My_video/output_0010.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0007.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0382.png (deflated 12%)
#   adding: content/TecoGAN/results/My_video/output_0429.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0099.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0215.png (deflated 8%)
#   adding: content/TecoGAN/results/My_video/output_0466.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0158.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0344.png (deflated 12%)
#   adding: content/TecoGAN/results/My_video/output_0312.png (deflated 7%)
#   adding: content/TecoGAN/results/My_video/output_0410.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0207.png (deflated 8%)
#   adding: content/TecoGAN/results/My_video/output_0109.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0017.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0072.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0231.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0055.png (deflated 8%)
#   adding: content/TecoGAN/results/My_video/output_0224.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0167.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0147.png (deflated 8%)
#   adding: content/TecoGAN/results/My_video/output_0118.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0452.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0033.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0080.png (deflated 12%)
#   adding: content/TecoGAN/results/My_video/output_0152.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0337.png (deflated 12%)
#   adding: content/TecoGAN/results/My_video/output_0307.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0345.png (deflated 12%)
#   adding: content/TecoGAN/results/My_video/output_0181.png (deflated 8%)
#   adding: content/TecoGAN/results/My_video/output_0433.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0379.png (deflated 12%)
#   adding: content/TecoGAN/results/My_video/output_0166.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0115.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0353.png (deflated 12%)
#   adding: content/TecoGAN/results/My_video/output_0305.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0325.png (deflated 12%)
#   adding: content/TecoGAN/results/My_video/output_0332.png (deflated 12%)
#   adding: content/TecoGAN/results/My_video/output_0228.png (deflated 8%)
#   adding: content/TecoGAN/results/My_video/output_0043.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0363.png (deflated 12%)
#   adding: content/TecoGAN/results/My_video/output_0378.png (deflated 13%)
#   adding: content/TecoGAN/results/My_video/output_0430.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0079.png (deflated 12%)
#   adding: content/TecoGAN/results/My_video/output_0183.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0127.png (deflated 11%)
#   adding: content/TecoGAN/results/My_video/output_0125.png (deflated 11%)
#   adding: content/TecoGAN/results/My_video/output_0308.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0037.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0124.png (deflated 11%)
#   adding: content/TecoGAN/results/My_video/output_0234.png (deflated 4%)
#   adding: content/TecoGAN/results/My_video/output_0058.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0126.png (deflated 11%)
#   adding: content/TecoGAN/results/My_video/output_0071.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0088.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0393.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0185.png (deflated 8%)
#   adding: content/TecoGAN/results/My_video/output_0028.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0239.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0355.png (deflated 11%)
#   adding: content/TecoGAN/results/My_video/output_0266.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0323.png (deflated 11%)
#   adding: content/TecoGAN/results/My_video/output_0049.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0331.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0059.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0272.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0042.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0416.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0249.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0197.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0296.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0179.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0280.png (deflated 7%)
#   adding: content/TecoGAN/results/My_video/output_0454.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0102.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0284.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0240.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0206.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0015.png (deflated 8%)
#   adding: content/TecoGAN/results/My_video/output_0251.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0074.png (deflated 11%)
#   adding: content/TecoGAN/results/My_video/output_0436.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0001.png (deflated 11%)
#   adding: content/TecoGAN/results/My_video/output_0139.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0175.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0417.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0086.png (deflated 11%)
#   adding: content/TecoGAN/results/My_video/output_0309.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0106.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0246.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0336.png (deflated 11%)
#   adding: content/TecoGAN/results/My_video/output_0083.png (deflated 11%)
#   adding: content/TecoGAN/results/My_video/output_0398.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0283.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0221.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0076.png (deflated 11%)
#   adding: content/TecoGAN/results/My_video/output_0356.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0470.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0366.png (deflated 12%)
#   adding: content/TecoGAN/results/My_video/output_0222.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0060.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0174.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0101.png (deflated 11%)
#   adding: content/TecoGAN/results/My_video/output_0120.png (deflated 11%)
#   adding: content/TecoGAN/results/My_video/output_0310.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0445.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0153.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0401.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0143.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0065.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0285.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0252.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0192.png (deflated 8%)
#   adding: content/TecoGAN/results/My_video/output_0438.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0451.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0078.png (deflated 11%)
#   adding: content/TecoGAN/results/My_video/output_0413.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0214.png (deflated 8%)
#   adding: content/TecoGAN/results/My_video/output_0196.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0352.png (deflated 11%)
#   adding: content/TecoGAN/results/My_video/output_0314.png (deflated 7%)
#   adding: content/TecoGAN/results/My_video/output_0318.png (deflated 12%)
#   adding: content/TecoGAN/results/My_video/output_0426.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0027.png (deflated 8%)
#   adding: content/TecoGAN/results/My_video/output_0349.png (deflated 12%)
#   adding: content/TecoGAN/results/My_video/output_0289.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0114.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0361.png (deflated 11%)
#   adding: content/TecoGAN/results/My_video/output_0230.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0014.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0391.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0468.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0161.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0399.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0350.png (deflated 11%)
#   adding: content/TecoGAN/results/My_video/output_0054.png (deflated 8%)
#   adding: content/TecoGAN/results/My_video/output_0456.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0348.png (deflated 11%)
#   adding: content/TecoGAN/results/My_video/output_0094.png (deflated 11%)
#   adding: content/TecoGAN/results/My_video/output_0315.png (deflated 11%)
#   adding: content/TecoGAN/results/My_video/output_0269.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0116.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0403.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0041.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0031.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0169.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0375.png (deflated 11%)
#   adding: content/TecoGAN/results/My_video/output_0235.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0446.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0459.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0140.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0005.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0450.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0300.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0163.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0244.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0415.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0434.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0008.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0119.png (deflated 11%)
#   adding: content/TecoGAN/results/My_video/output_0262.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0227.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0329.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0122.png (deflated 11%)
#   adding: content/TecoGAN/results/My_video/output_0425.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0260.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0038.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0298.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0036.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0418.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0271.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0464.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0077.png (deflated 11%)
#   adding: content/TecoGAN/results/My_video/output_0180.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0004.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0388.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0255.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0182.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0035.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0173.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0339.png (deflated 12%)
#   adding: content/TecoGAN/results/My_video/output_0358.png (deflated 11%)
#   adding: content/TecoGAN/results/My_video/output_0294.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0193.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0443.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0039.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0048.png (deflated 8%)
#   adding: content/TecoGAN/results/My_video/output_0259.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0292.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0342.png (deflated 12%)
#   adding: content/TecoGAN/results/My_video/output_0241.png (deflated 4%)
#   adding: content/TecoGAN/results/My_video/output_0030.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0404.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0465.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0414.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0469.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0431.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0370.png (deflated 12%)
#   adding: content/TecoGAN/results/My_video/output_0360.png (deflated 12%)
#   adding: content/TecoGAN/results/My_video/output_0046.png (deflated 8%)
#   adding: content/TecoGAN/results/My_video/output_0347.png (deflated 11%)
#   adding: content/TecoGAN/results/My_video/output_0229.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0063.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0400.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0070.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0084.png (deflated 12%)
#   adding: content/TecoGAN/results/My_video/output_0151.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0168.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0112.png (deflated 12%)
#   adding: content/TecoGAN/results/My_video/output_0198.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0093.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0145.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0362.png (deflated 12%)
#   adding: content/TecoGAN/results/My_video/output_0052.png (deflated 8%)
#   adding: content/TecoGAN/results/My_video/output_0150.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0354.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0448.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0383.png (deflated 12%)
#   adding: content/TecoGAN/results/My_video/output_0405.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0264.png (deflated 4%)
#   adding: content/TecoGAN/results/My_video/output_0133.png (deflated 11%)
#   adding: content/TecoGAN/results/My_video/output_0402.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0218.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0274.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0236.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0129.png (deflated 11%)
#   adding: content/TecoGAN/results/My_video/output_0075.png (deflated 11%)
#   adding: content/TecoGAN/results/My_video/output_0279.png (deflated 7%)
#   adding: content/TecoGAN/results/My_video/output_0100.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0302.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0131.png (deflated 11%)
#   adding: content/TecoGAN/results/My_video/output_0019.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0371.png (deflated 12%)
#   adding: content/TecoGAN/results/My_video/output_0326.png (deflated 12%)
#   adding: content/TecoGAN/results/My_video/output_0422.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0009.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0282.png (deflated 7%)
#   adding: content/TecoGAN/results/My_video/output_0291.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0327.png (deflated 12%)
#   adding: content/TecoGAN/results/My_video/output_0440.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0238.png (deflated 5%)
#   adding: content/TecoGAN/results/My_video/output_0223.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0178.png (deflated 9%)
#   adding: content/TecoGAN/results/My_video/output_0408.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0006.png (deflated 10%)
#   adding: content/TecoGAN/results/My_video/output_0424.png (deflated 6%)
#   adding: content/TecoGAN/results/My_video/output_0340.png (deflated 13%)
#   adding: content/TecoGAN/results/My_video/output_0184.png (deflated 9%)

# %%
# !cp

# %% [markdown]
#   Download Zip file

# %%
files.download('frames.zip')

# %%
import shutil


shutil.move("./frames.zip", "/content/drive/MyDrive/Deep_learning/GAN/frames.zip")
# Out:
# '/content/drive/MyDrive/Deep_learning/GAN/frames.zip'
